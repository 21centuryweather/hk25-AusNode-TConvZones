# %%
import intake
from easygems import healpix as egh
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Open catalog
cat = intake.open_catalog("https://digital-earths-global-hackathon.github.io/catalog/catalog.yaml")["online"]
# list(cat)

# %%
ds = cat["um_glm_n2560_RAL3p3"](zoom = 0).to_dask()
# Out:
# /home/pmauger/miniconda3/envs/HK25/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),

# %%
# Create a list to store rows
data = []

# Loop through dataset variables
for var in ds.data_vars:
    name = var
    desc = ds[var].attrs.get('long_name', var).replace('_', ' ').title()
    unit = ds[var].attrs.get('units', '')
    data.append([name, desc, unit])

# Create and print the DataFrame
df = pd.DataFrame(data, columns=["Variable Name", "Description", "Unit"])

# Display DataFrame with left-aligned headers and content
display(df.style.set_properties(**{'text-align': 'left'})
            .set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]))
# Out:
# <style type="text/css">
# #T_cad80 th {
#   text-align: left;
# }
# #T_cad80_row0_col0, #T_cad80_row0_col1, #T_cad80_row0_col2, #T_cad80_row1_col0, #T_cad80_row1_col1, #T_cad80_row1_col2, #T_cad80_row2_col0, #T_cad80_row2_col1, #T_cad80_row2_col2, #T_cad80_row3_col0, #T_cad80_row3_col1, #T_cad80_row3_col2, #T_cad80_row4_col0, #T_cad80_row4_col1, #T_cad80_row4_col2, #T_cad80_row5_col0, #T_cad80_row5_col1, #T_cad80_row5_col2, #T_cad80_row6_col0, #T_cad80_row6_col1, #T_cad80_row6_col2, #T_cad80_row7_col0, #T_cad80_row7_col1, #T_cad80_row7_col2, #T_cad80_row8_col0, #T_cad80_row8_col1, #T_cad80_row8_col2, #T_cad80_row9_col0, #T_cad80_row9_col1, #T_cad80_row9_col2, #T_cad80_row10_col0, #T_cad80_row10_col1, #T_cad80_row10_col2, #T_cad80_row11_col0, #T_cad80_row11_col1, #T_cad80_row11_col2, #T_cad80_row12_col0, #T_cad80_row12_col1, #T_cad80_row12_col2, #T_cad80_row13_col0, #T_cad80_row13_col1, #T_cad80_row13_col2, #T_cad80_row14_col0, #T_cad80_row14_col1, #T_cad80_row14_col2, #T_cad80_row15_col0, #T_cad80_row15_col1, #T_cad80_row15_col2, #T_cad80_row16_col0, #T_cad80_row16_col1, #T_cad80_row16_col2, #T_cad80_row17_col0, #T_cad80_row17_col1, #T_cad80_row17_col2, #T_cad80_row18_col0, #T_cad80_row18_col1, #T_cad80_row18_col2, #T_cad80_row19_col0, #T_cad80_row19_col1, #T_cad80_row19_col2, #T_cad80_row20_col0, #T_cad80_row20_col1, #T_cad80_row20_col2, #T_cad80_row21_col0, #T_cad80_row21_col1, #T_cad80_row21_col2, #T_cad80_row22_col0, #T_cad80_row22_col1, #T_cad80_row22_col2, #T_cad80_row23_col0, #T_cad80_row23_col1, #T_cad80_row23_col2, #T_cad80_row24_col0, #T_cad80_row24_col1, #T_cad80_row24_col2, #T_cad80_row25_col0, #T_cad80_row25_col1, #T_cad80_row25_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_cad80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cad80_level0_col0" class="col_heading level0 col0" >Variable Name</th>
#       <th id="T_cad80_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_cad80_level0_col2" class="col_heading level0 col2" >Unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cad80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cad80_row0_col0" class="data row0 col0" >clivi</td>
#       <td id="T_cad80_row0_col1" class="data row0 col1" >Atmosphere Mass Content Of Cloud Ice</td>
#       <td id="T_cad80_row0_col2" class="data row0 col2" >kg m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cad80_row1_col0" class="data row1 col0" >clt</td>
#       <td id="T_cad80_row1_col1" class="data row1 col1" >Cloud Area Fraction</td>
#       <td id="T_cad80_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cad80_row2_col0" class="data row2 col0" >clwvi</td>
#       <td id="T_cad80_row2_col1" class="data row2 col1" >Atmosphere Mass Content Of Cloud Condensed Water</td>
#       <td id="T_cad80_row2_col2" class="data row2 col2" >kg m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cad80_row3_col0" class="data row3 col0" >hflsd</td>
#       <td id="T_cad80_row3_col1" class="data row3 col1" >Surface Downward Latent Heat Flux</td>
#       <td id="T_cad80_row3_col2" class="data row3 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cad80_row4_col0" class="data row4 col0" >hfssd</td>
#       <td id="T_cad80_row4_col1" class="data row4 col1" >Surface Downward Sensible Heat Flux</td>
#       <td id="T_cad80_row4_col2" class="data row4 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cad80_row5_col0" class="data row5 col0" >huss</td>
#       <td id="T_cad80_row5_col1" class="data row5 col1" >Specific Humidity</td>
#       <td id="T_cad80_row5_col2" class="data row5 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cad80_row6_col0" class="data row6 col0" >pr</td>
#       <td id="T_cad80_row6_col1" class="data row6 col1" >Precipitation Flux</td>
#       <td id="T_cad80_row6_col2" class="data row6 col2" >kg m-2 s-1</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cad80_row7_col0" class="data row7 col0" >prs</td>
#       <td id="T_cad80_row7_col1" class="data row7 col1" >Solid Precipitation Flux</td>
#       <td id="T_cad80_row7_col2" class="data row7 col2" >kg m-2 s-1</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cad80_row8_col0" class="data row8 col0" >prw</td>
#       <td id="T_cad80_row8_col1" class="data row8 col1" >Atmosphere Mass Content Of Water Vapor</td>
#       <td id="T_cad80_row8_col2" class="data row8 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cad80_row9_col0" class="data row9 col0" >ps</td>
#       <td id="T_cad80_row9_col1" class="data row9 col1" >Surface Air Pressure</td>
#       <td id="T_cad80_row9_col2" class="data row9 col2" >Pa</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cad80_row10_col0" class="data row10 col0" >psl</td>
#       <td id="T_cad80_row10_col1" class="data row10 col1" >Air Pressure At Mean Sea Level</td>
#       <td id="T_cad80_row10_col2" class="data row10 col2" >Pa</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cad80_row11_col0" class="data row11 col0" >rlds</td>
#       <td id="T_cad80_row11_col1" class="data row11 col1" >Surface Downwelling Longwave Flux In Air</td>
#       <td id="T_cad80_row11_col2" class="data row11 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cad80_row12_col0" class="data row12 col0" >rldscs</td>
#       <td id="T_cad80_row12_col1" class="data row12 col1" >Surface Downwelling Longwave Flux In Air Clear Sky</td>
#       <td id="T_cad80_row12_col2" class="data row12 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cad80_row13_col0" class="data row13 col0" >rlut</td>
#       <td id="T_cad80_row13_col1" class="data row13 col1" >Toa Outgoing Longwave Flux</td>
#       <td id="T_cad80_row13_col2" class="data row13 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cad80_row14_col0" class="data row14 col0" >rlutcs</td>
#       <td id="T_cad80_row14_col1" class="data row14 col1" >Toa Outgoing Longwave Flux Clear Sky</td>
#       <td id="T_cad80_row14_col2" class="data row14 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cad80_row15_col0" class="data row15 col0" >rsds</td>
#       <td id="T_cad80_row15_col1" class="data row15 col1" >Surface Downwelling Shortwave Flux In Air</td>
#       <td id="T_cad80_row15_col2" class="data row15 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cad80_row16_col0" class="data row16 col0" >rsdscs</td>
#       <td id="T_cad80_row16_col1" class="data row16 col1" >Surface Downwelling Shortwave Flux In Air Clear Sky</td>
#       <td id="T_cad80_row16_col2" class="data row16 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_cad80_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cad80_row17_col0" class="data row17 col0" >rsdt</td>
#       <td id="T_cad80_row17_col1" class="data row17 col1" >Toa Incoming Shortwave Flux</td>
#       <td id="T_cad80_row17_col2" class="data row17 col2" >W m-2</td>
#     </tr>
#     <tr>
#       <th id="T_
